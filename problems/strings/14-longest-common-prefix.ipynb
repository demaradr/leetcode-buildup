# %% [markdown]
# # 14. Longest Common Prefix
#
# **LeetCode:** [Longest Common Prefix](https://leetcode.com/problems/longest-common-prefix/)
# **Difficulty:** Easy
# **Core skills:** string indexing, nested loops, early exit, building a result string
#
# ## Before you start
#
# 1. **Read the problem on LeetCode** (link above) so you know the inputs, outputs, and examples.
# 2. **Write your algorithm in plain English** — on paper or in a new cell below. How do you walk the strings? When do you stop? How do you build the answer? Do this *before* you try to code the full solution.
# 3. Work through the skill exercises in order. They practice the same moves your algorithm will need.
# 4. When the exercises feel natural, implement `longestCommonPrefix` in **Part 2**. Record yourself when you solve it.
#
# Use `print()` liberally while you code — that is normal debugging, not cheating.

# %% [markdown]
# *(Optional)* Your algorithm in English:
#
# 1. I start with … because …
# 2. For each index `i`, I …
# 3. I stop when …
# 4. I build the answer by …
# 5. I return …

# %% [markdown]
# ---
# ## Part 1 — Skills
#
# Tiny exercises that map directly to this problem. Do them in order.

# %% [markdown]
# ### Exercise 1 — Print every character in a word
#
# Given `word = "apple"`, print one character per line:
#
# ```
# a
# p
# p
# l
# e
# ```

# %%
word = "apple"

for i in word:
    print(i)

# %% [markdown]
# ### Exercise 2 — Print index and character
#
# Same word. Print `index character` on each line, e.g. `0 a`, `1 p`, …

# %%
word = "apple"

# TODO

# %% [markdown]
# ### Exercise 3 — Compare two words letter by letter
#
# Compare `word1` and `word2` at each index. Print lines like `f == f`, `l == l`, …
# **Stop when one word runs out of letters** (do not go past the shorter word).

# %%
word1 = "flower"
word2 = "flow"

# TODO

# %% [markdown]
# ### Exercise 4 — Print every word in a list

# %%
words = ["dog", "cat", "bird"]

# TODO

# %% [markdown]
# ### Exercise 5 — First letter of every word
#
# For the same list, print only the first character of each word (one per line).

# %%
words = ["dog", "cat", "bird"]

# TODO

# %% [markdown]
# ### Exercise 6 — One index across all words
#
# Pick a fixed index `i` and print `words[j][i]` for every word `j`.
#
# Try `i = 0`, then `i = 1`, with:
#
# ```python
# words = ["flower", "flow", "flight"]
# ```
#
# This is the core idea behind longest common prefix: *same position, every word*.

# %%
words = ["flower", "flow", "flight"]
i = 0  # change to 1, 2, ... and re-run

# TODO: print the character at index i for each word

# %% [markdown]
# ### Exercise 7 — Stop when letters don't match
#
# At a given index, if any letter differs from the first word's letter at that index, **stop** and print something like `mismatch at index 2`.
#
# Example at index 2 for `["flower", "flow", "flight"]`: you should see `o`, `o`, `i` → mismatch.

# %%
words = ["flower", "flow", "flight"]

# TODO: loop index i from 0 upward; at each i, check all words; break on mismatch

# %% [markdown]
# ### Exercise 8 — Stop when index is out of bounds
#
# If **any** word is too short for index `i`, stop.
# Example: `["car", "care", "cat"]` — at index 3, `"car"` has no character at index 3.

# %%
words = ["car", "care", "cat"]

# TODO: same loop idea as above, but also stop if i >= len(any word)

# %% [markdown]
# ### Exercise 9 — Build a string one character at a time
#
# Start with `result = ""`. Add `'a'`, then `'p'`, then `'p'` and print `result` after each add. You should see `"a"`, then `"ap"`, then `"app"`.

# %%
result = ""

# TODO

# %% [markdown]
# ### Exercise 10 — Build the common prefix of two words by hand
#
# For `"flower"` and `"flow"`, add matching letters to `result` until they disagree or a word ends.
# Expected result: `"flow"`.
#
# Do **not** worry about optimal Big-O here — just get the right answer with loops.

# %%
word1 = "flower"
word2 = "flow"
result = ""

# TODO

# %% [markdown]
# ---
# ## Part 2 — Solve
#
# ### Problem
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string `""`.
#
# **Examples:**
#
# | Input | Output |
# |-------|--------|
# | `["flower","flow","flight"]` | `"fl"` |
# | `["dog","racecar","car"]` | `""` |
# | `["ab","a"]` | `"a"` |
#
# **Constraints:**
#
# - `1 <= strs.length <= 200`
# - `0 <= strs[i].length <= 200`
# - `strs[i]` consists of only lowercase English letters

# %% [markdown]
# ### Your solution
#
# Implement `longestCommonPrefix` below.
# When it works, **record yourself solving it** (explain your loops and stopping conditions out loud).
#
# Then run the test cell to verify.

# %%
def longestCommonPrefix(strs: list[str]) -> str:
  # TODO: your implementation
  pass

# %% [markdown]
# ### Tests (run after you implement)
#
# These are sanity checks — if one fails, print inside your function to see where logic diverges.

# %%
assert longestCommonPrefix(["flower", "flow", "flight"]) == "fl"
assert longestCommonPrefix(["dog", "racecar", "car"]) == ""
assert longestCommonPrefix(["ab", "a"]) == "a"
assert longestCommonPrefix(["a"]) == "a"
assert longestCommonPrefix(["", "b"]) == ""

print("All tests passed.")

# %% [markdown]
# ### After you pass
#
# - Wait a couple of hours, then solve **from scratch** again the actual LeetCode.
# - Optional: paste your YouTube link here for future you:
#
# ```
# My walkthrough:
# ```
