# %% [markdown]
# # Easy problems — practice by category
#
# Re-solve every **Easy** problem in this repo without opening LeetCode. No skill drills — just the problem, your code, and tests.
#
# ## How to use
#
# 1. Pick a category below.
# 2. Read the short problem statement.
# 3. Implement the empty `Solution` cell from scratch.
# 4. Run the test cell under it.
# 5. Clear the solution cell and do it again later.
#
# Stuck? Scroll to **Answer key** at the bottom (or open that problem's `*-solutions.ipynb`).
#
# ## Contents
#
# | Category | Problems |
# |----------|----------|
# | **Arrays** | 1 Two Sum · 217 Contains Duplicate · 242 Valid Anagram |
# | **Strings** | 14 Longest Common Prefix |
# | **Sliding window** | 121 Best Time to Buy and Sell Stock |
# | **Two pointers** | 125 Valid Palindrome |
#
# > Medium problems (e.g. 347) are not in this notebook.

# %% [markdown]
# ---
# # Arrays

# %% [markdown]
# ## 1. Two Sum
#
# [LeetCode](https://leetcode.com/problems/two-sum/) · Easy
#
# Given `nums` and `target`, return indices of the two numbers that add up to `target`.
# Each input has exactly one solution; you may not use the same element twice. Order of indices does not matter for the idea — match the expected pairs in the tests.
#
# | nums | target | Output |
# |------|--------|--------|
# | `[2,7,11,15]` | `9` | `[0,1]` |
# | `[3,2,4]` | `6` | `[1,2]` |
# | `[3,3]` | `6` | `[0,1]` |

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        # TODO
        pass

# %%
sol = Solution()

assert sol.twoSum([2, 7, 11, 15], 9) == [0, 1]
assert sol.twoSum([3, 2, 4], 6) == [1, 2]
assert sol.twoSum([3, 3], 6) == [0, 1]

print("1. Two Sum — passed.")

# %% [markdown]
# ## 217. Contains Duplicate
#
# [LeetCode](https://leetcode.com/problems/contains-duplicate/) · Easy
#
# Return `True` if any value appears at least twice in `nums`; otherwise `False`.
#
# | nums | Output |
# |------|--------|
# | `[1,2,3,1]` | `True` |
# | `[1,2,3,4]` | `False` |

# %%
class Solution:
    def containsDuplicate(self, nums: list[int]) -> bool:
        # TODO
        pass

# %%
sol = Solution()

assert sol.containsDuplicate([1, 2, 3, 1]) is True
assert sol.containsDuplicate([1, 2, 3, 4]) is False
assert sol.containsDuplicate([1, 1, 1, 3, 3, 4, 3, 2, 4, 2]) is True
assert sol.containsDuplicate([1]) is False

print("217. Contains Duplicate — passed.")

# %% [markdown]
# ## 242. Valid Anagram
#
# [LeetCode](https://leetcode.com/problems/valid-anagram/) · Easy
#
# Return `True` if `t` is an anagram of `s` (same characters with the same counts).
#
# | s | t | Output |
# |---|---|--------|
# | `"anagram"` | `"nagaram"` | `True` |
# | `"rat"` | `"car"` | `False` |

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        # TODO
        pass

# %%
sol = Solution()

assert sol.isAnagram("anagram", "nagaram") is True
assert sol.isAnagram("rat", "car") is False
assert sol.isAnagram("aacc", "ccac") is False
assert sol.isAnagram("a", "a") is True
assert sol.isAnagram("ab", "a") is False

print("242. Valid Anagram — passed.")

# %% [markdown]
# ---
# # Strings

# %% [markdown]
# ## 14. Longest Common Prefix
#
# [LeetCode](https://leetcode.com/problems/longest-common-prefix/) · Easy
#
# Find the longest common prefix string among an array of strings. Return `""` if there is none.
#
# | strs | Output |
# |------|--------|
# | `["flower","flow","flight"]` | `"fl"` |
# | `["dog","racecar","car"]` | `""` |

# %%
class Solution:
    def longestCommonPrefix(self, strs: list[str]) -> str:
        # TODO
        pass

# %%
sol = Solution()

assert sol.longestCommonPrefix(["flower", "flow", "flight"]) == "fl"
assert sol.longestCommonPrefix(["dog", "racecar", "car"]) == ""
assert sol.longestCommonPrefix(["ab", "a"]) == "a"
assert sol.longestCommonPrefix(["a"]) == "a"
assert sol.longestCommonPrefix(["", "b"]) == ""

print("14. Longest Common Prefix — passed.")

# %% [markdown]
# ---
# # Sliding window

# %% [markdown]
# ## 121. Best Time to Buy and Sell Stock
#
# [LeetCode](https://leetcode.com/problems/best-time-to-buy-and-sell-stock/) · Easy
#
# `prices[i]` is the stock price on day `i`. Buy on one day and sell on a later day. Return the max profit, or `0` if you cannot profit.
#
# | prices | Output |
# |--------|--------|
# | `[7,1,5,3,6,4]` | `5` |
# | `[7,6,4,3,1]` | `0` |

# %%
class Solution:
    def maxProfit(self, prices: list[int]) -> int:
        # TODO
        pass

# %%
sol = Solution()

assert sol.maxProfit([7, 1, 5, 3, 6, 4]) == 5
assert sol.maxProfit([7, 6, 4, 3, 1]) == 0
assert sol.maxProfit([2, 4, 1]) == 2
assert sol.maxProfit([1]) == 0
assert sol.maxProfit([1, 2]) == 1

print("121. Best Time to Buy and Sell Stock — passed.")

# %% [markdown]
# ---
# # Two pointers

# %% [markdown]
# ## 125. Valid Palindrome
#
# [LeetCode](https://leetcode.com/problems/valid-palindrome/) · Easy
#
# After converting to lowercase and removing non-alphanumeric characters, return whether `s` reads the same forward and backward.
#
# | s | Output |
# |---|--------|
# | `"A man, a plan, a canal: Panama"` | `True` |
# | `"race a car"` | `False` |
# | `" "` | `True` |

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        # TODO
        pass

# %%
sol = Solution()

assert sol.isPalindrome("A man, a plan, a canal: Panama") is True
assert sol.isPalindrome("race a car") is False
assert sol.isPalindrome(" ") is True
assert sol.isPalindrome("0P") is False
assert sol.isPalindrome("a.") is True

print("125. Valid Palindrome — passed.")

# %% [markdown]
# ---
# # Answer key
#
# **Stop here if you are still practicing.**
# Reference implementations for each problem above. Match the approach from this repo's guides when you can.

# %% [markdown]
# ### 1. Two Sum — hash map

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        prev_map = {}  # value -> index

        for i, n in enumerate(nums):
            diff = target - n
            if diff in prev_map:
                return [prev_map[diff], i]
            prev_map[n] = i

        return []

# %% [markdown]
# ### 217. Contains Duplicate — hash set

# %%
class Solution:
    def containsDuplicate(self, nums: list[int]) -> bool:
        seen = set()

        for num in nums:
            if num in seen:
                return True
            seen.add(num)

        return False

# %% [markdown]
# ### 242. Valid Anagram — two count maps

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        if len(s) != len(t):
            return False

        count_s, count_t = {}, {}

        for i in range(len(s)):
            count_s[s[i]] = 1 + count_s.get(s[i], 0)
            count_t[t[i]] = 1 + count_t.get(t[i], 0)

        for c in count_s:
            if count_s[c] != count_t.get(c, 0):
                return False

        return True

# %% [markdown]
# ### 14. Longest Common Prefix — column by column

# %%
class Solution:
    def longestCommonPrefix(self, strs: list[str]) -> str:
        if not strs:
            return ""

        result = ""

        for i in range(len(strs[0])):
            char = strs[0][i]
            for word in strs[1:]:
                if i >= len(word) or word[i] != char:
                    return result
            result += char

        return result

# %% [markdown]
# ### 121. Best Time to Buy and Sell Stock — sliding window

# %%
class Solution:
    def maxProfit(self, prices: list[int]) -> int:
        l, r = 0, 1
        max_profit = 0

        while r < len(prices):
            if prices[l] < prices[r]:
                profit = prices[r] - prices[l]
                max_profit = max(max_profit, profit)
            else:
                l = r
            r += 1

        return max_profit

# %% [markdown]
# ### 125. Valid Palindrome — two pointers

# %%
def is_alphanumeric(c):
    return (ord("A") <= ord(c) <= ord("Z") or
            ord("a") <= ord(c) <= ord("z") or
            ord("0") <= ord(c) <= ord("9"))


class Solution:
    def isPalindrome(self, s: str) -> bool:
        l, r = 0, len(s) - 1

        while l < r:
            while l < r and not is_alphanumeric(s[l]):
                l += 1
            while l < r and not is_alphanumeric(s[r]):
                r -= 1

            if s[l].lower() != s[r].lower():
                return False

            l += 1
            r -= 1

        return True
